# %%
import logging
from handnfoot import cardtable
from handnfoot import handnfoot
# Out:
# [B1] (32)

# %%
logging.basicConfig(format='%(levelname)s: %(message)s', level=logging.DEBUG)
g = handnfoot.HNFGame()
g.add_player(cardtable.Player("J", precision=5, speed=1.2), handnfoot.Strategy())
g.add_player(cardtable.Player("S", precision=10, speed=1), handnfoot.Strategy())
g.add_player(cardtable.Player("L", precision=7, speed=1), handnfoot.Strategy())
g.add_player(cardtable.Player("A", precision=15, speed=.9), handnfoot.Strategy())
#g.game_setup()
#g.round_setup()
g.start()
#g.display()
# Out:
# INFO: Setting up game
# INFO: Setting up round 1

# %%
g.players[0].display()
for i in range(20):
    g.play_turn(player = g.players[0])
g.players[0].display()
# Out:
# DEBUG: Player J draws [7H[JC]
# DEBUG: Player J discards *B leaving [3H[5H[6C[6C[6D[6H[7H[AD[JC[KC[TC[TS]
# DEBUG: Player J draws [JH[3D]
# DEBUG: Player J discards 5H leaving [3H[3D[6C[6C[6D[6H[7H[AD[JC[JH[KC[TC[TS]
# DEBUG: Player J draws [KD[8H]
# DEBUG: Player J discards 7H leaving [3H[3D[6C[6C[6D[6H[8H[AD[JC[JH[KC[KD[TC[TS]
# DEBUG: Player J draws [4H[8C]
# DEBUG: Player J discards 4H leaving [3H[3D[6C[6C[6D[6H[8H[8C[AD[JC[JH[KC[KD[TC[TS]
# DEBUG: Player J draws [QH[QS]
# DEBUG: Player J discards AD leaving [3H[3D[6C[6C[6D[6H[8H[8C[JC[JH[KC[KD[QH[QS[TC[TS]
# DEBUG: Player J draws [7C[QH]
# DEBUG: Player J discards 7C leaving [3H[3D[6C[6C[6D[6H[8H[8C[JC[JH[KC[KD[QH[QS[QH[TC[TS]
# DEBUG: Player J draws [AD[JC]
# DEBUG: Player J lays down [6C[6C[6D[6H]
# DEBUG: Player J lays down [JC[JH[JC]
# DEBUG: Player J lays down [QH[QS[QH]
# DEBUG: Player J discards AD leaving [3H[3D[8H[8C[KC[KD[TC[TS]
# DEBUG: Player J draws [2H[4S]
# DEBUG: Player J discards 2H leaving [3H[3D[4S[8H[8C[KC[KD[TC[TS]
# DEBUG: Player J draws [7D[5S]
# DEBUG: Player J discards 4S leaving [3H[3D[5S[7D[8H[8C[KC[KD[TC[TS]
# DEBUG: Player J draws [AH[7C]
# DEBUG: Player J discards 5S leaving [3H[3D[7D[7C[8H[8C[AH[KC[KD[TC[TS]
# DEBUG: Player J draws [8D[AD]
# DEBUG: Player J lays down [8H[8C[8D]
# DEBUG: Player J discards 3H leaving [3D[7D[7C[AH[AD[KC[KD[TC[TS]
# DEBUG: Player J draws [8H[5H]
# DEBUG: Player J lays down [8H]
# DEBUG: Player J discards 3D leaving [5H[7D[7C[AH[AD[KC[KD[TC[TS]
# DEBUG: Player J draws [4C[7D]
# DEBUG: Player J lays down [7D[7C[7D]
# DEBUG: Player J discards 4C leaving [5H[AH[AD[KC[KD[TC[TS]
# DEBUG: Player J draws [AH[QH]
# DEBUG: Player J lays down [AH[AD[AH]
# DEBUG: Player J lays down [QH]
# DEBUG: Player J discards 5H leaving [KC[KD[TC[TS]
# DEBUG: Player J draws [7H[4D]
# DEBUG: Player J lays down [7H]
# DEBUG: Player J discards 4D leaving [KC[KD[TC[TS]
# DEBUG: Player J draws [*R[JC]
# DEBUG: Player J lays down [JC]
# DEBUG: Player J discards *R leaving [KC[KD[TC[TS]
# DEBUG: Player J draws [JS[6D]
# DEBUG: Player J lays down [6D]
# DEBUG: Player J lays down [JS]
# DEBUG: Player J discards KC leaving [KD[TC[TS]
# DEBUG: Player J draws [8C[7H]
# DEBUG: Player J lays down [7H]
# DEBUG: Player J lays down [8C]
# DEBUG: Player J discards KD leaving [TC[TS]
# DEBUG: Player J draws [3S[3D]
# DEBUG: Player J discards 3S leaving [3D[TC[TS]
# DEBUG: Player J draws [6H[9S]
# DEBUG: Player J lays down [6H]
# DEBUG: Player J discards 3D leaving [9S[TC[TS]
# J:
# complete:
# down:
# hand: [*B[3H[5H[6C[6C[6D[6H[AD[KC[TC[TS]
# foot: [R3] (11)
# J:
# complete:
# down: [6C[6C[6D[6H[6D[6H]  [JC[JH[JC[JC[JS]  [QH[QS[QH[QH]  [8H[8C[8D[8H[8C]  [7D[7C[7D[7H[7H]  [AH[AD[AH]
# hand: [9S[TC[TS]
# foot: [R3] (11)

# %%
from IPython.display import display, HTML, Markdown
def css_styling():
    styles = open("./styles/cardtable.css", "r").read()
    return f"<style>{styles}</style>"
s = css_styling()

#for card in g.players[0].get_hand().cards:
#    s += (card.get_HTML())
s += g.players[0].get_hand().get_HTML()
#display(HTML('<span style="font-size:90px; background-color:white;">'+s+'</span>'))
display(HTML(s))
#print(s)

s = '<span style="font-size: 70px">'
for card in g.players[0].get_hand().cards:
    s += (card.get_HTML(type="unicode"))
s += "</span>"
display(HTML(s))

print(g.players[0].get_hand())
# Out:
# <style>
# .cardtable_hand {
#     padding-right: 50px; /* Leave room for last card overflow */
# }
#
# .cardtable_hand .cardtable_card {
#     overflow: clip;
#     max-width: 20px;
# }
#
# .cardtable_card {
#     display: inline-block;
# }
# body span.cardtable_card img {
#     background-color:white;
#     border-radius: 5px;
#     border: solid 1px black;
#     width: 70px !important;
#     height: 102px;
# }
# </style><span class="cardtable_hand"><span class="cardtable_card"><img src="handnfoot/pcassets/png/9_of_spades.png"></span><span class="cardtable_card"><img src="handnfoot/pcassets/png/10_of_clubs.png"></span><span class="cardtable_card"><img src="handnfoot/pcassets/png/10_of_spades.png"></span></span>
# <span style="font-size: 70px"><span style="background:white;color:BLACK">🂩</span><span style="background:white;color:BLACK">🃚</span><span style="background:white;color:BLACK">🂪</span></span>
# [9S[TC[TS]

# %%
from IPython.display import display, HTML
s = """<style>
.pile {
    xdisplay: grid;
    xgrid-auto-flow: column;
    xgrid-template-column: 15px;
}
.cardtable_card {
    xgrid-row: 1;
    width: 70px;
    overflow-x: hidden;
}
</style>"""
#s += '<span class="pile">'
for card in g.players[0].get_hand().cards:
    s += (card.get_HTML())
#s += '</span>'
#display(HTML('<span style="font-size:90px; background-color:white;">'+s+'</span>'))
display(HTML(s))
#print(s)
# Out:
# <style>
# .pile {
#     xdisplay: grid;
#     xgrid-auto-flow: column;
#     xgrid-template-column: 15px;
# }
# .cardtable_card {
#     xgrid-row: 1;
#     width: 70px;
#     overflow-x: hidden;
# }
# </style><span class="cardtable_card"><img src="handnfoot/pcassets/png/9_of_spades.png"></span><span class="cardtable_card"><img src="handnfoot/pcassets/png/10_of_clubs.png"></span><span class="cardtable_card"><img src="handnfoot/pcassets/png/10_of_spades.png"></span>
